# %%
import requests
import pandas as pd
import math
import data_reader
from tqdm import tqdm

from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
import numpy as np

tqdm.pandas()
stemmer = PorterStemmer()
lemmatizer=WordNetLemmatizer()
# Out:
# C:\Users\phoec\anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
FILE_DIR = "./custom_lexicons/sentidd/"

# %% [markdown]
# ## Read in Directional Words

# %%
DIRECTIONAL_WORDS_FILEPATH = FILE_DIR+"directional_words.csv"
directional_words_df = pd.read_csv(DIRECTIONAL_WORDS_FILEPATH)
directional_words_df
# Out:
#          token label    stemmed
# 0   accelerate    up    acceler
# 1      advance    up     advanc
# 2        award    up      award
# 3       better    up     better
# 4        climb    up      climb
# 5       double    up      doubl
# 6       faster    up     faster
# 7         gain    up       gain
# 8         grow    up       grow
# 9       higher    up     higher
# 10    increase    up    increas
# 11        jump    up       jump
# 12     quicken    up    quicken
# 13     rebound    up    rebound
# 14     recover    up      recov
# 15        rise    up       rise
# 16        rose    up       rose
# 17     step-up    up    step-up
# 18       surge    up       surg
# 19          up    up         up
# 20   constrain  down  constrain
# 21  decelerate  down    deceler
# 22     decline  down     declin
# 23    decrease  down    decreas
# 24        down  down       down
# 25        drop  down       drop
# 26        fall  down       fall
# 27        fell  down       fell
# 28      slower  down     slower
# 29      weaken  down     weaken
# 30      weaker  down     weaker

# %% [markdown]
# ## Helper Functions

# %%
def assign_direction_dependency_type(text, label):
    tokens = word_tokenize(text)
    up_cnt, down_cnt = 0, 0
    for token in tokens:
        if stemmer.stem(token) in directional_words_df[directional_words_df['label']=='up'].stemmed.values:
            up_cnt += 1
        if stemmer.stem(token) in directional_words_df[directional_words_df['label']=='down'].stemmed.values:
            down_cnt += 1
    score = up_cnt - down_cnt
    if (score > 0 and label == 'positive') or (score < 0 and label == 'negative'): return 'proportional'
    if (score > 0 and label == 'negative') or (score < 0 and label == 'positive'): return 'inversely_proportional'
    
def get_preprocessed_nouns(text):
    words = word_tokenize(text)
    nouns = [token for token, tag in pos_tag(words) if tag in ['NN', 'NNS', 'NNP', 'NNPS']]
    nouns = [lemmatizer.lemmatize(token) for token in nouns if len(token)>1]
    return np.array(nouns)

def select_frequent_tokens(list_of_tokens, min_count):
    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False, min_df=min_count)
    vectorizer.fit_transform(list_of_tokens)
    selected_tokens = vectorizer.vocabulary_.keys()
    selected_tokens = [item for item in selected_tokens if stemmer.stem(item) not in directional_words_df.stemmed.values]
    return selected_tokens

def count_sentences_containing(list_of_tokens, word):
    count = 0
    for tokens in list_of_tokens:
        if word in tokens:
            count += 1
    return count

def count_sentences_not_containing(list_of_tokens, word):
    count = 0
    for tokens in list_of_tokens:
        if word not in tokens:
            count += 1
    return count

def pmi(df, word, t):
    n = len(df)
    a = count_sentences_containing(df[df.direction_dependency==t].nouns, word)
    b = count_sentences_containing(df[df.direction_dependency!=t].nouns, word)
    c = count_sentences_not_containing(df[df.direction_dependency==t].nouns, word)
    return (n*a)/((a+b)*(a+c))

def pmi_combined(df, word):
    pmi_prop = pmi(df, word, 'proportional')
    pmi_invprop = pmi(df, word, 'inversely_proportional')
    if pmi_prop > pmi_invprop: return abs(pmi_prop)
    elif pmi_prop < pmi_invprop: return -abs(pmi_invprop)
    else: return 0
    
def extract_token_score(tokens, scores, t):
    if t == 'proportional':
        if np.max(scores) <= 0: return (None, None)
        return (tokens[np.argmax(scores)], np.max(scores))
    elif t == 'inversely_proportional':
        if np.max(scores) >= 0: return (None, None)
        return (tokens[np.argmin(scores)], np.min(scores))
    
def construct_senti_dd(train_df, dd_filepath, senti_dd_filepath):
    df = train_df
    print("Number of headlines = {}".format(len(df)))
        
    df['direction_dependency'] = df.progress_apply(lambda x: assign_direction_dependency_type(x['headline'], x['label']), axis=1)
    df.dropna(subset=['direction_dependency'], inplace=True)

    df['nouns'] = df['headline'].progress_apply(lambda x: get_preprocessed_nouns(x))
    selected_tokens = select_frequent_tokens(df.nouns.values, 6)
    print('\n\nSelected tokens ({})\n{}'.format(len(selected_tokens), selected_tokens))
    
    df['nouns'] = df['nouns'].progress_apply(lambda nouns: [token for token in nouns if token in selected_tokens])
    df = df[df['nouns'].map(len) != 0]
    print('\n\nNumber of proportional type headlines = {}\t inversely_proportional type headlines = {}'.format(len(df[df.direction_dependency=='proportional']), len(df[df.direction_dependency=='inversely_proportional'])))
    
    # Estimation of the Strength of Association Between a Word and a Direction-DependencyType
    lexicon_df = pd.DataFrame({'token': selected_tokens})
    lexicon_df['pmi'] = lexicon_df['token'].progress_apply(lambda x: pmi_combined(df, x))
    
    # Extraction of Direction-dependent Words
    df['scores'] = df['nouns'].progress_apply(lambda x: np.array([lexicon_df[lexicon_df.token==token].iloc[0].pmi for token in x]))

    df['token_score'] = df.progress_apply(lambda x: extract_token_score(x['nouns'], x['scores'], x['direction_dependency']), axis=1)
    df['entity'] = df['token_score'].progress_apply(lambda x: x[0])
    df['entity_score'] = df['token_score'].progress_apply(lambda x: x[1])
    df.drop(columns=['token_score'], inplace=True)

    dd = pd.DataFrame.from_records(
        list(zip(df.direction_dependency.values, df.entity.values, df.entity_score.values)),
                                   columns=['direction_dependency', 'entity', 'score'])
    dd.dropna(subset=['score'], inplace=True)
    dd.drop_duplicates(subset=['direction_dependency', 'entity'], inplace=True)

    proportional_words = dd[dd.direction_dependency=='proportional'].entity.values
    inversely_proportional_words = dd[dd.direction_dependency=='inversely_proportional'].entity.values
    print('\n\nProportional type entities ({})\n{}'.format(len(proportional_words), ', '.join(proportional_words)))
    print('\nInversely proportional type entities ({})\n{}'.format(len(inversely_proportional_words), 
                                                                   ', '.join(inversely_proportional_words)))
    
    dd.to_csv(dd_filepath, index=False)
    print('Created', dd_filepath)
    
    # Senti-DD Construction based on the List of Directional Words and the Direction-dependent Words
    up_words = directional_words_df[directional_words_df.label=='up'].stemmed.values
    down_words = directional_words_df[directional_words_df.label=='down'].stemmed.values

    records = []
    records.extend([('positive', entity, direction) for entity in proportional_words for direction in up_words])
    records.extend([('positive', entity, direction) for entity in inversely_proportional_words for direction in down_words])
    records.extend([('negative', entity, direction) for entity in proportional_words for direction in down_words])
    records.extend([('negative', entity, direction) for entity in inversely_proportional_words for direction in up_words])
    senti_dd = pd.DataFrame.from_records(records, columns=['sentiment', 'entity', 'directional_word'])
    print('\n\nNumber of positive pairs: {}\t negative pairs: {}'.format(len(senti_dd[senti_dd.sentiment=='positive']), len(senti_dd[senti_dd.sentiment=='negative'])))
    
    senti_dd.to_csv(senti_dd_filepath, index=False)
    print('Created', senti_dd_filepath)

# %% [markdown]
# ## 1. Sentidd using data4

# %%
data4 = data_reader.read_data4("lexicon", True)
data4
# Out:
#        Sentiment    User_id  \
# 0        Bearish  442859953
# 1        Bearish  442859939
# 2        Bearish  442859938
# 3        Bearish  442859889
# 4        Bearish  442859884
# ...          ...        ...
# 680928   Bullish  235142330
# 680929   Bullish  234896323
# 680930   Bullish  231400354
# 680931   Bullish  231399519
# 680932   Bullish  231397503
#
#                                                   Message        Date  \
# 0           crypto is even worthless if there is no world  2022-03-10
# 1                  why is it crashing so fast anyone know  2022-03-10
# 2         bulls got trapped again how can it be l m f a o  2022-03-10
# 3                       by friday cmon make me rich daddy  2022-03-10
# 4                                algo last night predicts  2022-03-10
# ...                                                   ...         ...
# 680928                                        bullish rsi  2020-08-10
# 680929              time to back up the truck and load up  2020-08-09
# 680930  this things going to pump harder than arnold s...  2020-07-28
# 680931                                  daddy wants gains  2020-07-28
# 680932                      solana will jill eth and do x  2020-07-28
#
#              Time Symbol
# 0       08:39:18Z    SPY
# 1       08:39:09Z    SPY
# 2       08:39:08Z    SPY
# 3       08:38:22Z    SPY
# 4       08:38:19Z    SPY
# ...           ...    ...
# 680928  18:46:14Z  SOL.X
# 680929  22:37:22Z  SOL.X
# 680930  01:25:14Z  SOL.X
# 680931  01:19:47Z  SOL.X
# 680932  01:06:35Z  SOL.X
#
# [680933 rows x 6 columns]

# %%
data4 = data4[['Message', 'Sentiment']]
data4.columns = ['headline', 'label']
data4['label'] = data4['label'].apply(lambda x: "negative" if x=="Bearish" else "positive")
data4
# Out:
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                  headline     label
# 0           crypto is even worthless if there is no world  negative
# 1                  why is it crashing so fast anyone know  negative
# 2         bulls got trapped again how can it be l m f a o  negative
# 3                       by friday cmon make me rich daddy  negative
# 4                                algo last night predicts  negative
# ...                                                   ...       ...
# 680928                                        bullish rsi  positive
# 680929              time to back up the truck and load up  positive
# 680930  this things going to pump harder than arnold s...  positive
# 680931                                  daddy wants gains  positive
# 680932                      solana will jill eth and do x  positive
#
# [680933 rows x 2 columns]

# %%
dd_filepath_data4 = (FILE_DIR+'direction_dependent_entities_data4.csv')
senti_dd_filepath_data4 = (FILE_DIR+'sentidd_data4.csv')
construct_senti_dd(data4, dd_filepath_data4, senti_dd_filepath_data4)
# Out:
#   0%|                                                                            | 19/680933 [00:00<2:05:17, 90.57it/s]
# Number of headlines = 680933
# 100%|████████████████████████████████████████████████████████████████████████| 680933/680933 [2:29:44<00:00, 75.79it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|█████████████████████████████████████████████████████████████████████████| 119740/119740 [04:50<00:00, 412.02it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   3%|█▉                                                                       | 3260/119740 [00:00<00:06, 16800.96it/s]
# Selected tokens (5777)
# ['bull', 'warning', 'run', 'oil', 'system', 'eye', 'musk', 'economy', 'fuel', 'look', 'spy', 'future', 'problem', 'digit', 'inflation', 'enjoy', 'bitcoin', 'commodity', 'today', 'gold', 'watch', 'ssr', 'get', 'put', 'congrats', 'yesterday', 'wednesday', 'trap', 'stock', 'portfolio', 'tomorrow', 'corn', 'hater', 'wow', 'fucker', 'day', 'downtrend', 'rinse', 'repeat', 'lol', 'gg', 'money', 'printer', 'gon', 'indicator', 'btc', 'vice', 'versa', 'tmr', 'bloodbath', 'people', 'wheat', 'america', 'war', 'pump', 'shit', 'time', 'tesla', 'something', 'world', 'energy', 'tower', 'govt', 'jp', 'morgan', 'civilization', 'year', 'counting', 'reason', 'gas', 'price', 'cost', 'rally', 'bounce', 'support', 'resistance', 'line', 'baby', 'head', 'action', 'number', 'bear', 'following', 'market', 'break', 'whats', 'crude', 'sanction', 'power', 'liftoff', 'rate', 'balance', 'sheet', 'stimulus', 'valuation', 'supply', 'chain', 'shortage', 'high', 'mexican', 'wall', 'cut', 'car', 'guy', 'china', 'dollar', 'ruble', 'spx', 'fed', 'consumer', 'thing', 'low', 'recession', 'sector', 'im', 'need', 'straw', 'bond', 'guess', 'opportunity', 'nigeria', 'capacity', 'work', 'min', 'account', 'month', 'arent', 'research', 'funding', 'pentagon', 'thats', 'hand', 'week', 'stonks', 'futes', 'fear', 'cpi', 'short', 'vix', 'bye', 'goodbye', 'percent', 'morning', 'folk', 'biden', 'control', 'course', 'way', 'case', 'trump', 'example', 'fault', 'administration', 'credit', 'cent', 'alltime', 'want', 'place', 'slice', 'throat', 'move', 'movement', 'train', 'chart', 'anything', 'currency', 'illusion', 'trader', 'pay', 'pool', 'pain', 'let', 'diarrhea', 'point', 'workman', 'laugh', 'plate', 'stone', 'layer', 'material', 'processor', 'amd', 'intel', 'exception', 'position', 'chip', 'component', 'earth', 'element', 'purpose', 'exchange', 'condition', 'trend', 'covid', 'restriction', 'site', 'news', 'hour', 'insider', 'spring', 'summer', 'cheeseburger', 'life', 'there', 'he', 'issue', 'basis', 'hike', 'miss', 'anyone', 'seller', 'sideline', 'excuse', 'asf', 'bitcoiners', 'brandon', 'touch', 'upside', 'potential', 'window', 'cash', 'index', 'buy', 'interest', 'circulation', 'earnings', 'company', 'growth', 'investor', 'return', 'liquidity', 'buyer', 'intelligence', 'effort', 'korea', 'missile', 'launch', 'lady', 'gentleman', 'po', 'lord', 'vaccine', 'virus', 'well', 'plan', 'couldnt', 'push', 'ceo', 'arm', 'stance', 'blessing', 'nikkei', 'wonder', 'right', 'pandemic', 'shape', 'act', 'keep', 'putin', 'blame', 'dam', 'wtf', 'attempt', 'mkt', 'hasnt', 'amazon', 'wave', 'motion', 'piece', 'nothing', 'pie', 'blue', 'bar', 'inch', 'flag', 'explosion', 'ok', 'talk', 'send', 'podcast', 'episode', 'youre', 'fight', 'country', 'yo', 'instagram', 'twitter', 'post', 'submarine', 'lambos', 'usd', 'perfect', 'game', 'lmfao', 'nose', 'relative', 'washington', 'bottom', 'isnt', 'everyone', 'psychology', 'night', 'tonight', 'prediction', 'call', 'qqq', 'board', 'reflection', 'official', 'idiot', 'fertilizer', 'fool', 'march', 'print', 'meaning', 'season', 'demand', 'russia', 'pressure', 'data', 'deadcat', 'couple', 'permabears', 'age', 'fintwit', 'crash', 'everything', 'wealth', 'hey', 'fuck', 'lifetime', 'magnitude', 'collapse', 'harm', 'family', 'eco', 'toilet', 'box', 'environment', 'water', 'lock', 'p', 'face', 'detail', 'headline', 'mass', 'neighbor', 'quick', 'sell', 'town', 'heavy', 'join', 'degenerate', 'gambling', 'loss', 'ppi', 'stay', 'algo', 'yall', 'till', 'lunch', 'fact', 'fud', 'technical', 'jpow', 'end', 'moron', 'level', 'algos', 'gap', 'business', 'ma', 'track', 'health', 'report', 'theyve', 'while', 'matter', 'string', 'forecast', 'yea', 'trading', 'bb', 'channel', 'doesnt', 'qa', 'order', 'disaster', 'idea', 'warehouse', 'graphic', 'card', 'amount', 'space', 'bearish', 'fantasy', 'crisis', 'shop', 'cap', 'thanks', 'depression', 'stuff', 'option', 'friday', 'side', 'trade', 'bring', 'step', 'lfg', 'split', 'sht', 'sense', 'michael', 'burry', 'tlt', 'youve', 'catalyst', 'y ...
# 100%|███████████████████████████████████████████████████████████████████████| 119740/119740 [00:11<00:00, 10088.83it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   0%|                                                                                 | 2/5777 [00:00<07:56, 12.12it/s]
# Number of proportional type headlines = 76638	 inversely_proportional type headlines = 34731
# 100%|██████████████████████████████████████████████████████████████████████████████| 5777/5777 [16:01<00:00,  6.01it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 111369/111369 [12:59<00:00, 142.89it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|███████████████████████████████████████████████████████████████████████| 111369/111369 [00:06<00:00, 17626.63it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████████████████████████████████████████████████████████████████| 111369/111369 [00:00<00:00, 989779.28it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|█████████████████████████████████████████████████████████████████████| 111369/111369 [00:00<00:00, 1006373.80it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\phoec\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Proportional type entities (2451)
# bitcoin, future, gg, baby, liftoff, spx, low, sector, funding, short, morning, train, exchange, miss, push, nikkei, tomorrow, ceo, podcast, perfect, age, eco, town, algo, till, technical, gap, track, qa, cap, time, beginning, limit, moon, signal, chart, glimpse, congrats, ripper, tmr, watch, robinhood, ticker, back, alongside, tommorow, station, momentum, swing, amazon, theyll, release, leg, monster, confident, shitter, analyst, super, regardless, get, thankful, tonight, pattern, cc, share, ema, farm, covering, reversal, closing, resolution, let, high, consolidation, hold, revenue, pullback, follow, contract, splash, stop, rare, profit, play, keep, metaverse, confidence, mastercard, exhaustion, dip, jan, bandwagon, bro, tuesday, happens, hour, digit, target, extension, launch, daddy, th, elliott, reuters, dax, feeling, tute, nonsense, oi, volume, run, basement, bottom, move, earthquake, bb, partnership, faa, delivery, date, opportunity, app, itll, resistance, alternative, imo, night, way, ash, sale, male, dope, shortterm, productivity, currency, melt, mofos, load, block, dow, position, internet, announcement, boom, dildo, agreement, hulk, ft, pennant, kong, application, overnight, cover, chance, come, knife, beautiful, capital, coin, burn, harris, term, elevator, wait, subscriber, bitch, breaker, clip, staircase, pt, mc, manufacturer, stack, rofl, user, smell, trending, alert, plan, incoming, catalyst, room, minimum, robotics, domino, fin, crypto, shes, look, pick, eod, btch, boy, value, trading, buyback, brainer, open, race, bashers, demand, google, trade, fast, smart, twit, hang, breakthrough, ace, quit, tight, pitch, btc, wow, hong, xtrades, parade, support, advantage, st, addict, complete, van, watcher, folk, momo, swim, asia, page, buddy, shock, worth, symbol, taste, float, place, reset, export, freedom, clinton, opinion, regret, source, shoot, candle, buy, efficient, pain, in, coaster, member, reward, mf, court, payment, lotto, upside, clarity, timeline, hacker, cyber, forum, mil, lock, well, stocktwits, sight, announces, shout, ol, penalty, fakeout, thanks, discord, steam, account, aware, pm, membership, couple, squeeze, beer, floor, weekend, bong, cryptocurrencies, portfolio, parabolic, process, omg, capability, wave, cup, fucker, lead, nice, youll, creation, check, purpose, eye, s, min, cheer, institution, beast, stair, mention, eat, fam, touch, overreaction, dumper, roll, nope, reflection, iq, whim, megaphone, exploration, biatch, friend, power, owner, cheap, arabia, okay, millionaire, resume, anybody, enjoy, zelenskyy, tom, pootin, army, lottery, advice, building, technology, match, fiat, moral, worry, corner, btw, add, truck, hidden, midmarch, sore, beam, step, ath, speed, cow, ground, jpm, jones, grab, november, team, sleep, shopify, review, na, continuation, breakout, kidney, commence, glad, period, shakeout, dividend, manipulate, thx, transaction, whale, comon, below, equipment, handle, breather, worldwide, mechanism, wed, indo, leadership, discount, wheel, id, woo, footprint, picker, miner, board, dad, backwards, ride, mode, vwap, grandchild, runup, hail, pls, naz, join, coast, afternoon, habit, hurry, fib, movie, otc, hub, headfake, beauty, capitalization, identity, upgrade, sunday, channel, use, schedule, eow, work, newton, approval, remains, bargain, return, ba, diligence, roku, hi, london, transfer, ethereum, japan, hooker, dinner, start, buck, who, beach, sure, slingshot, mine, proportion, constant, pool, clock, key, stranger, vp, begging, fute, pair, hr, coverage, focus, education, list, copper, agree, warrior, overtime, reactor, token, version, instant, heartbeat, rocket, message, build, fee, function, website, goal, chatter, concept, hasnt, basis, theta, glory, peasant, tesla, experience, platinum, solution, investment, inception, son, hide, therefore, twitter, berlin, bios, guard, invades, swap, yuan, fever, division, hello, boat, tf, quad, zone, profitsrecord, anti, ripple, grip, range, love, rain, se ...
#
# Inversely proportional type entities (1615)
# trap, money, oil, number, cost, guy, china, goodbye, po, wtf, ppi, jpow, vix, cpi, ear, food, bulltards, wheres, war, inflation, futes, fraud, wen, market, psaki, top, put, print, coincidence, nickel, reason, paycheck, putin, bull, mm, hell, stupidity, sucker, dump, history, chernobyl, fed, peloton, bear, im, somethings, rn, economy, stock, january, fake, march, crash, aid, call, barrel, florida, everything, rent, qe, volatility, april, nothing, cant, involvement, spring, people, sky, bruh, option, uncertainty, intrest, civilian, class, item, lmfao, cushion, fauci, today, default, second, plz, lol, poland, nuke, body, russia, amd, trust, sideline, cock, drunk, angel, fill, dude, hotter, prop, bidens, reality, gas, wth, joe, bring, hope, lunacy, minute, pump, scalp, lmao, ship, dam, conflict, teleprompter, haha, bubble, tank, brandon, dem, rip, listen, dummy, biden, spike, shit, ukraine, bullshit, show, gallon, garbage, slaughterhouse, dare, futs, stagflation, yield, stonk, liberal, moron, yesterday, nazi, biggie, problem, expense, part, wti, powell, idea, fertilizer, zelensky, permabulls, cringe, meltdown, president, performs, keystone, chin, meh, recession, democrat, disaster, mantra, gon, strange, hunter, close, highway, stonks, theyre, oof, racist, kid, circus, dollar, huh, iran, bar, imbecile, dat, scapegoat, boomer, wall, k, selloff, jesus, america, welfare, air, smh, metal, damnit, cotton, day, b, pretend, wont, dang, destruction, commodity, lololol, crude, crime, cash, yikes, fear, scope, mentality, pop, situation, line, twat, spy, belief, home, voter, bid, cool, country, costco, troop, trucker, heart, price, house, btd, ratio, submission, printer, prophet, job, signature, qt, rate, monitor, sanction, hopium, row, whole, ponzi, dementia, slope, employment, gut, tape, hike, joke, business, thats, bloodbath, brent, valuation, energy, greedy, junk, friday, fk, buying, maker, percent, afghanistan, sea, calm, guess, god, issue, attack, damage, radiation, fucking, everyone, treat, bois, europe, invasion, plant, health, hey, rally, sense, truth, chicago, government, course, jail, threat, cmon, nap, pray, hair, wedge, everythings, bastard, shoulder, netflix, wire, propping, joes, confirms, premium, crazy, piggy, doesnt, isnt, lookout, tbh, manipulation, airline, tax, need, tension, piece, week, fook, wh, reaction, bp, bond, toll, street, insanity, pipe, treasury, good, man, greed, iranian, road, pig, disgrace, chief, weakness, dte, tho, care, clown, guidance, intraday, trash, ball, reverse, news, general, deflation, see, dos, petroleum, payroll, pelosi, blame, ma, trump, lmaoooo, pandemic, weed, yacht, unemployment, remark, mentor, as, fuck, he, debt, face, kamala, soo, economics, nancy, sotu, sentence, basket, shoe, file, desperation, earnings, swan, bullard, month, casino, delusion, violation, afraid, chop, poots, secretary, bringing, society, pull, idiot, risk, kiev, realtime, ppt, thesis, aapl, whammy, damn, bail, tsla, welp, un, hitler, scream, hunting, brandons, sack, collapse, youve, pumpers, hoax, nut, bearish, agenda, pole, shitshow, leap, dreamer, thing, taper, constitution, there, weather, capitulation, west, qqq, rookie, workman, fuel, corn, horse, negotiation, damm, cent, perma, republican, anyone, lie, nflx, one, lot, latter, bomb, mfers, gold, chicken, meeting, fool, hahah, usa, minister, ruble, someone, honey, year, weapon, citizen, ukrainian, case, covid, retracement, oh, yeah, madman, decade, soldier, wheat, craziness, monday, cheat, personality, breakdown, school, potato, insult, enemy, courage, thursday, heat, bet, peter, bounce, gambler, sweep, tag, communist, bye, effect, viagra, data, arent, nasdaq, military, pce, ignore, insane, toyota, wolf, make, perspective, bully, ten, casualty, ring, cause, phone, werent, gtfoh, vxx, dont, snd, con, imagine, dime, turmoil, fighter, algos, protester, cyberattack, end, fart, rule, plunge, ecb, justification, forming, imbalance, duty, eh, level, math, imma, taiwan, jim ...
# Created ./custom_lexicons/sentidd/direction_dependent_entities_data4.csv
#
#
# Number of positive pairs: 66785	 negative pairs: 59261
# Created ./custom_lexicons/sentidd/sentidd_data4.csv

# %% [markdown]
# ## 2. Sentidd using data1

# %%
data1 = data_reader.read_data1("dataframe", True)
data1
# Out:
#                                            text_cleaned  Label
# 0                downgrades stocks investing tradeideas      0
# 1     looking sexy this morning break on volume and ...      1
# 2     stock hasnt moved much since first few weeks a...      1
# 3     whole foods may feel price competition but wil...      1
# 4     apples iphone se could be doing better than ex...      1
# ...                                                 ...    ...
# 2018  hold through all the media bs and you will be ...      1
# 2019    i love blood like a vampirekeep bleeding for me      0
# 2020                yea dude airplanes are still flying      1
# 2021  ten year yield weekly year yield still very be...      1
# 2022  the best scenario going forward is this stock ...      0
#
# [2023 rows x 2 columns]

# %%
data1.columns = ['headline', 'label']
data1['label'] = data1['label'].apply(lambda x: "negative" if x==0 else "positive")
data1
# Out:
#                                                headline     label
# 0                downgrades stocks investing tradeideas  negative
# 1     looking sexy this morning break on volume and ...  positive
# 2     stock hasnt moved much since first few weeks a...  positive
# 3     whole foods may feel price competition but wil...  positive
# 4     apples iphone se could be doing better than ex...  positive
# ...                                                 ...       ...
# 2018  hold through all the media bs and you will be ...  positive
# 2019    i love blood like a vampirekeep bleeding for me  negative
# 2020                yea dude airplanes are still flying  positive
# 2021  ten year yield weekly year yield still very be...  positive
# 2022  the best scenario going forward is this stock ...  negative
#
# [2023 rows x 2 columns]

# %%
dd_filepath_data1 = (FILE_DIR+'direction_dependent_entities_data1.csv')
senti_dd_filepath_data1 = (FILE_DIR+'sentidd_data1.csv')
construct_senti_dd(data1, dd_filepath_data1, senti_dd_filepath_data1)
# Out:
#   1%|▊                                                                               | 20/2023 [00:00<00:21, 92.39it/s]
# Number of headlines = 2023
# 100%|█████████████████████████████████████████████████████████████████████████████| 2023/2023 [00:19<00:00, 102.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 368/368 [00:00<00:00, 770.85it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 368/368 [00:00<00:00, 183925.63it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 37/37 [00:00<00:00, 389.46it/s]
#   0%|                                                                                          | 0/234 [00:00<?, ?it/s]
# Selected tokens (37)
# ['apple', 'stock', 'week', 'google', 'look', 'sale', 'weekend', 'call', 'morning', 'afternoon', 'trade', 'intel', 'point', 'today', 'earnings', 'market', 'day', 'low', 'dont', 'longs', 'buying', 'move', 'watch', 'chart', 'share', 'oil', 'price', 'year', 'time', 'china', 'gap', 'support', 'deal', 'metal', 'starbucks', 'report', 'sign']
#
#
# Number of proportional type headlines = 179	 inversely_proportional type headlines = 55
# 100%|██████████████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 1004.86it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|█████████████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 17992.72it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|████████████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 225624.63it/s]
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|████████████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 231532.70it/s]
# Proportional type entities (22)
# stock, look, weekend, call, afternoon, earnings, market, dont, longs, watch, chart, share, oil, year, week, time, support, trade, deal, intel, point, price
#
# Inversely proportional type entities (8)
# google, sale, day, china, gap, metal, starbucks, today
# Created ./custom_lexicons/sentidd/direction_dependent_entities_data1.csv
#
#
# Number of positive pairs: 528	 negative pairs: 402
# Created ./custom_lexicons/sentidd/sentidd_data1.csv
# C:\Users\phoec\anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\phoec\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
